# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('C:/Users/murth/Desktop/tree.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#edges = cv2.Canny(gray,50,150,apertureSize = 3)
cv2.line(img, (100,200), (200, 150), (0, 0, 255), 1)

cv2.imwrite('C:/Users/murth/Desktop/houghlines10.jpg',img)
plt.imshow(img)
plt.show()
